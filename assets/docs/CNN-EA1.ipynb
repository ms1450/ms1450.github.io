# %%
# Get datasets from: https://drive.google.com/open?id=16w02wuMOqoLm6-YlM-rhAC1uZthO-2A3
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import numpy as np

# authenticate user credentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# download datasets from GDrive
# uncomment the dataset needed

# Small_10_100 Dataset
downloaded = drive.CreateFile({'id': '19wcJs9TdIwhT85TGdsaw1GV1ypbLnOpK'})
downloaded.GetContentFile('small_10_100.zip')
# Large_10_1000 Dataset
#downloaded = drive.CreateFile({'id': '1pghUuYyaYsuwDCA7Ow1Y601kGl6qPboL'})
#downloaded.GetContentFile('large_10_1000.zip')
# Large_95_100 Dataset
#downloaded = drive.CreateFile({'id': '1f-o1ygRlTZtvhbC9naP721khFJicbp-n'})
#downloaded.GetContentFile('large_95_100.zip')
# Full Dataset
#downloaded = drive.CreateFile({'id': '1SSwOHbTTPQJcpjyMtl9s2vdFGNonCKV7'})
#downloaded.GetContentFile('full.zip')

# unzip the datasets
# uncomment the dataset needed
# !unzip -o small_10_100.zip
#!unzip -o large_10_1000.zip
#!unzip -o large_95_100.zip
#!unzip -o full.zip
# Out:
# Archive:  small_10_100.zip
#    creating: small_10_100/
#   inflating: small_10_100/1-27
#   inflating: small_10_100/1-26
#   inflating: small_10_100/1-25
#   inflating: small_10_100/1-24
#   inflating: small_10_100/1-23
#   inflating: small_10_100/1-22
#   inflating: small_10_100/1-21
#   inflating: small_10_100/1-20
#   inflating: small_10_100/1-19
#   inflating: small_10_100/1-18
#   inflating: small_10_100/1-17
#   inflating: small_10_100/1-16
#   inflating: small_10_100/1-15
#   inflating: small_10_100/1-14
#   inflating: small_10_100/1-13
#   inflating: small_10_100/1-12
#   inflating: small_10_100/1-11
#   inflating: small_10_100/1-10
#   inflating: small_10_100/1-9
#   inflating: small_10_100/1-8
#   inflating: small_10_100/1-7
#   inflating: small_10_100/1-6
#   inflating: small_10_100/1-5
#   inflating: small_10_100/1-4
#   inflating: small_10_100/1-3
#   inflating: small_10_100/1-2
#   inflating: small_10_100/1-1
#   inflating: small_10_100/1-0
#   inflating: small_10_100/0-99
#   inflating: small_10_100/0-98
#   inflating: small_10_100/0-97
#   inflating: small_10_100/0-96
#   inflating: small_10_100/0-95
#   inflating: small_10_100/0-94
#   inflating: small_10_100/0-93
#   inflating: small_10_100/0-92
#   inflating: small_10_100/0-91
#   inflating: small_10_100/0-90
#   inflating: small_10_100/0-89
#   inflating: small_10_100/0-88
#   inflating: small_10_100/0-87
#   inflating: small_10_100/0-86
#   inflating: small_10_100/0-85
#   inflating: small_10_100/0-84
#   inflating: small_10_100/0-83
#   inflating: small_10_100/0-82
#   inflating: small_10_100/0-81
#   inflating: small_10_100/0-80
#   inflating: small_10_100/0-79
#   inflating: small_10_100/0-78
#   inflating: small_10_100/0-77
#   inflating: small_10_100/0-76
#   inflating: small_10_100/0-75
#   inflating: small_10_100/0-74
#   inflating: small_10_100/0-73
#   inflating: small_10_100/0-72
#   inflating: small_10_100/0-71
#   inflating: small_10_100/0-70
#   inflating: small_10_100/0-69
#   inflating: small_10_100/0-68
#   inflating: small_10_100/0-67
#   inflating: small_10_100/0-66
#   inflating: small_10_100/0-65
#   inflating: small_10_100/0-64
#   inflating: small_10_100/0-63
#   inflating: small_10_100/0-62
#   inflating: small_10_100/0-61
#   inflating: small_10_100/0-60
#   inflating: small_10_100/0-59
#   inflating: small_10_100/0-58
#   inflating: small_10_100/0-57
#   inflating: small_10_100/0-56
#   inflating: small_10_100/0-55
#   inflating: small_10_100/0-54
#   inflating: small_10_100/0-53
#   inflating: small_10_100/0-52
#   inflating: small_10_100/0-51
#   inflating: small_10_100/0-50
#   inflating: small_10_100/0-49
#   inflating: small_10_100/0-48
#   inflating: small_10_100/0-47
#   inflating: small_10_100/0-46
#   inflating: small_10_100/0-45
#   inflating: small_10_100/0-44
#   inflating: small_10_100/0-43
#   inflating: small_10_100/0-42
#   inflating: small_10_100/0-41
#   inflating: small_10_100/0-40
#   inflating: small_10_100/0-39
#   inflating: small_10_100/0-38
#   inflating: small_10_100/0-37
#   inflating: small_10_100/0-36
#   inflating: small_10_100/0-35
#   inflating: small_10_100/0-34
#   inflating: small_10_100/0-33
#   inflating: small_10_100/0-32
#   inflating: small_10_100/0-31
#   inflating: small_10_100/0-30
#   inflating: small_10_100/0-29
#   inflating: small_10_100/0-28
#   inflating: small_10_100/0-27
#   inflating: small_10_100/0-26
#   inflating: small_10_100/0-25
#   inflating: small_10_100/0-24
#   inflating: small_10_100/0-23
#   inflating: small_10_100/0-22
#   inflating: small_10_100/0-21
#   inflating: small_10_100/0-20
#   inflating: small_10_100/0-19
#   inflating: small_10_100/0-18
#   inflating: small_10_100/0-17
#   inflating: small_10_100/0-16
#   inflating: small_10_100/0-15
#   inflating: small_10_100/0-14
#   inflating: small_10_100/0-13
#   inflating: small_10_100/0-12
#   inflating: small_10_100/0-11
#   inflating: small_10_100/0-10
#   inflating: small_10_100/0-9
#   inflating: small_10_100/0-8
#   inflating: small_10_100/0-7
#   inflating: small_10_100/0-6
#   inflating: small_10_100/0-5
#   inflating: small_10_100/0-4
#   inflating: small_10_100/0-3
#   inflating: small_10_100/0-2
#   inflating: small_10_100/0-1
#   inflating: small_10_100/0-0
#   inflating: small_10_100/2-55
#   inflating: small_10_100/2-54
#   inflating: small_10_100/2-53
#   inflating: small_10_100/2-52
#   inflating: small_10_100/2-51
#   inflating: small_10_100/2-50
#   inflating: small_10_100/2-49
#   inflating: small_10_100/2-48
#   inflating: small_10_100/2-47
#   inflating: small_10_100/2-46
#   inflating: small_10_100/2-45
#   inflating: small_10_100/2-44
#   inflating: small_10_100/2-43
#   inflating: small_10_100/2-42
#   inflating: small_10_100/2-41
#   inflating: small_10_100/2-40
#   inflating: small_10_100/2-39
#   inflating: small_10_100/2-38
#   inflating: small_10_100/2-37
#   inflating: small_10_100/2-36
#   inflating: small_10_100/2-35
#   inflating: small_10_100/2-34
#   inflating: small_10_100/2-33
#   inflating: small_10_100/2-32
#   inflating: small_10_100/2-31
#   inflating: small_10_100/2-30
#   inflating: small_10_100/2-29
#   inflating: small_10_100/2-28
#   inflating: small_10_100/2-27
#   inflating: small_10_100/2-26
#   inflating: small_10_100/2-25
#   inflating: small_10_100/2-24
#   inflating: small_10_100/2-23
#   inflating: small_10_100/2-22
#   inflating: small_10_100/2-21
#   inflating: small_10_100/2-20
#   inflating: small_10_100/2-19
#   inflating: small_10_100/2-18
#   inflating: small_10_100/2-17
#   inflating: small_10_100/2-16
#   inflating: small_10_100/2-15
#   inflating: small_10_100/2-14
#   inflating: small_10_100/2-13
#   inflating: small_10_100/2-12
#   inflating: small_10_100/2-11
#   inflating: small_10_100/2-10
#   inflating: small_10_100/2-9
#   inflating: small_10_100/2-8
#   inflating: small_10_100/2-7
#   inflating: small_10_100/2-6
#   inflating: small_10_100/2-5
#   inflating: small_10_100/2-4
#   inflating: small_10_100/2-3
#   inflating: small_10_100/2-2
#   inflating: small_10_100/2-1
#   inflating: small_10_100/2-0
#   inflating: small_10_100/1-99
#   inflating: small_10_100/1-98
#   inflating: small_10_100/1-97
#   inflating: small_10_100/1-96
#   inflating: small_10_100/1-95
#   inflating: small_10_100/1-94
#   inflating: small_10_100/1-93
#   inflating: small_10_100/1-92
#   inflating: small_10_100/1-91
#   inflating: small_10_100/1-90
#   inflating: small_10_100/1-89
#   inflating: small_10_100/1-88
#   inflating: small_10_100/1-87
#   inflating: small_10_100/1-86
#   inflating: small_10_100/1-85
#   inflating: small_10_100/1-84
#   inflating: small_10_100/1-83
#   inflating: small_10_100/1-82
#   inflating: small_10_100/1-81
#   inflating: small_10_100/1-80
#   inflating: small_10_100/1-79
#   inflating: small_10_100/1-78
#   inflating: small_10_100/1-77
#   inflating: small_10_100/1-76
#   inflating: small_10_100/1-75
#   inflating: small_10_100/1-74
#   inflating: small_10_100/1-73
#   inflating: small_10_100/1-72
#   inflating: small_10_100/1-71
#   inflating: small_10_100/1-70
#   inflating: small_10_100/1-69
#   inflating: small_10_100/1-68
#   inflating: small_10_100/1-67
#   inflating: small_10_100/1-66
#   inflating: small_10_100/1-65
#   inflating: small_10_100/1-64
#   inflating: small_10_100/1-63
#   inflating: small_10_100/1-62
#   inflating: small_10_100/1-61
#   inflating: small_10_100/1-60
#   inflating: small_10_100/1-59
#   inflating: small_10_100/1-58
#   inflating: small_10_100/1-57
#   inflating: small_10_100/1-56
#   inflating: small_10_100/1-55
#   inflating: small_10_100/1-54
#   inflating: small_10_100/1-53
#   inflating: small_10_100/1-52
#   inflating: small_10_100/1-51
#   inflating: small_10_100/1-50
#   inflating: small_10_100/1-49
#   inflating: small_10_100/1-48
#   inflating: small_10_100/1-47
#   inflating: small_10_100/1-46
#   inflating: small_10_100/1-45
#   inflating: small_10_100/1-44
#   inflating: small_10_100/1-43
#   inflating: small_10_100/1-42
#   inflating: small_10_100/1-41
#   inflating: small_10_100/1-40
#   inflating: small_10_100/1-39
#   inflating: small_10_100/1-38
#   inflating: small_10_100/1-37
#   inflating: small_10_100/1-36
#   inflating: small_10_100/1-35
#   inflating: small_10_100/1-34
#   inflating: small_10_100/1-33
#   inflating: small_10_100/1-32
#   inflating: small_10_100/1-31
#   inflating: small_10_100/1-30
#   inflating: small_10_100/1-29
#   inflating: small_10_100/1-28
#   inflating: small_10_100/3-83
#   inflating: small_10_100/3-82
#   inflating: small_10_100/3-81
#   inflating: small_10_100/3-80
#   inflating: small_10_100/3-79
#   inflating: small_10_100/3-78
#   inflating: small_10_100/3-77
#   inflating: small_10_100/3-76
#   inflating: small_10_100/3-75
#   inflating: small_10_100/3-74
#   inflating: small_10_100/3-73
#   inflating: small_10_100/3-72
#   inflating: small_10_100/3-71
#   inflating: small_10_100/3-70
#   inflating: small_10_100/3-69
#   inflating: small_10_100/3-68
#   inflating: small_10_100/3-67
#   inflating: small_10_100/3-66
#   inflating: small_10_100/3-65
#   inflating: small_10_100/3-64
#   inflating: small_10_100/3-63
#   inflating: small_10_100/3-62
#   inflating: small_10_100/3-61
#   inflating: small_10_100/3-60
#   inflating: small_10_100/3-59
#   inflating: small_10_100/3-58
#   inflating: small_10_100/3-57
#   inflating: small_10_100/3-56
#   inflating: small_10_100/3-55
#   inflating: small_10_100/3-54
#   inflating: small_10_100/3-53
#   inflating: small_10_100/3-52
#   inflating: small_10_100/3-51
#   inflating: small_10_100/3-50
#   inflating: small_10_100/3-49
#   inflating: small_10_100/3-48
#   inflating: small_10_100/3-47
#   inflating: small_10_100/3-46
#   inflating: small_10_100/3-45
#   inflating: small_10_100/3-44
#   inflating: small_10_100/3-43
#   inflating: small_10_100/3-42
#   inflating: small_10_100/3-41
#   inflating: small_10_100/3-40
#   inflating: small_10_100/3-39
#   inflating: small_10_100/3-38
#   inflating: small_10_100/3-37
#   inflating: small_10_100/3-36
#   inflating: small_10_100/3-35
#   inflating: small_10_100/3-34
#   inflating: small_10_100/3-33
#   inflating: small_10_100/3-32
#   inflating: small_10_100/3-31
#   inflating: small_10_100/3-30
#   inflating: small_10_100/3-29
#   inflating: small_10_100/3-28
#   inflating: small_10_100/3-27
#   inflating: small_10_100/3-26
#   inflating: small_10_100/3-25
#   inflating: small_10_100/3-24
#   inflating: small_10_100/3-23
#   inflating: small_10_100/3-22
#   inflating: small_10_100/3-21
#   inflating: small_10_100/3-20
#   inflating: small_10_100/3-19
#   inflating: small_10_100/3-18
#   inflating: small_10_100/3-17
#   inflating: small_10_100/3-16
#   inflating: small_10_100/3-15
#   inflating: small_10_100/3-14
#   inflating: small_10_100/3-13
#   inflating: small_10_100/3-12
#   inflating: small_10_100/3-11
#   inflating: small_10_100/3-10
#   inflating: small_10_100/3-9
#   inflating: small_10_100/3-8
#   inflating: small_10_100/3-7
#   inflating: small_10_100/3-6
#   inflating: small_10_100/3-5
#   inflating: small_10_100/3-4
#   inflating: small_10_100/3-3
#   inflating: small_10_100/3-2
#   inflating: small_10_100/3-1
#   inflating: small_10_100/3-0
#   inflating: small_10_100/2-99
#   inflating: small_10_100/2-98
#   inflating: small_10_100/2-97
#   inflating: small_10_100/2-96
#   inflating: small_10_100/2-95
#   inflating: small_10_100/2-94
#   inflating: small_10_100/2-93
#   inflating: small_10_100/2-92
#   inflating: small_10_100/2-91
#   inflating: small_10_100/2-90
#   inflating: small_10_100/2-89
#   inflating: small_10_100/2-88
#   inflating: small_10_100/2-87
#   inflating: small_10_100/2-86
#   inflating: small_10_100/2-85
#   inflating: small_10_100/2-84
#   inflating: small_10_100/2-83
#   inflating: small_10_100/2-82
#   inflating: small_10_100/2-81
#   inflating: small_10_100/2-80
#   inflating: small_10_100/2-79
#   inflating: small_10_100/2-78
#   inflating: small_10_100/2-77
#   inflating: small_10_100/2-76
#   inflating: small_10_100/2-75
#   inflating: small_10_100/2-74
#   inflating: small_10_100/2-73
#   inflating: small_10_100/2-72
#   inflating: small_10_100/2-71
#   inflating: small_10_100/2-70
#   inflating: small_10_100/2-69
#   inflating: small_10_100/2-68
#   inflating: small_10_100/2-67
#   inflating: small_10_100/2-66
#   inflating: small_10_100/2-65
#   inflating: small_10_100/2-64
#   inflating: small_10_100/2-63
#   inflating: small_10_100/2-62
#   inflating: small_10_100/2-61
#   inflating: small_10_100/2-60
#   inflating: small_10_100/2-59
#   inflating: small_10_100/2-58
#   inflating: small_10_100/2-57
#   inflating: small_10_100/2-56
#   inflating: small_10_100/5-11
#   inflating: small_10_100/5-10
#   inflating: small_10_100/5-9
#   inflating: small_10_100/5-8
#   inflating: small_10_100/5-7
#   inflating: small_10_100/5-6
#   inflating: small_10_100/5-5
#   inflating: small_10_100/5-4
#   inflating: small_10_100/5-3
#   inflating: small_10_100/5-2
#   inflating: small_10_100/5-1
#   inflating: small_10_100/5-0
#   inflating: small_10_100/4-99
#   inflating: small_10_100/4-98
#   inflating: small_10_100/4-97
#   inflating: small_10_100/4-96
#   inflating: small_10_100/4-95
#   inflating: small_10_100/4-94
#   inflating: small_10_100/4-93
#   inflating: small_10_100/4-92
#   inflating: small_10_100/4-91
#   inflating: small_10_100/4-90
#   inflating: small_10_100/4-89
#   inflating: small_10_100/4-88
#   inflating: small_10_100/4-87
#   inflating: small_10_100/4-86
#   inflating: small_10_100/4-85
#   inflating: small_10_100/4-84
#   inflating: small_10_100/4-83
#   inflating: small_10_100/4-82
#   inflating: small_10_100/4-81
#   inflating: small_10_100/4-80
#   inflating: small_10_100/4-79
#   inflating: small_10_100/4-78
#   inflating: small_10_100/4-77
#   inflating: small_10_100/4-76
#   inflating: small_10_100/4-75
#   inflating: small_10_100/4-74
#   inflating: small_10_100/4-73
#   inflating: small_10_100/4-72
#   inflating: small_10_100/4-71
#   inflating: small_10_100/4-70
#   inflating: small_10_100/4-69
#   inflating: small_10_100/4-68
#   inflating: small_10_100/4-67
#   inflating: small_10_100/4-66
#   inflating: small_10_100/4-65
#   inflating: small_10_100/4-64
#   inflating: small_10_100/4-63
#   inflating: small_10_100/4-62
#   inflating: small_10_100/4-61
#   inflating: small_10_100/4-60
#   inflating: small_10_100/4-59
#   inflating: small_10_100/4-58
#   inflating: small_10_100/4-57
#   inflating: small_10_100/4-56
#   inflating: small_10_100/4-55
#   inflating: small_10_100/4-54
#   inflating: small_10_100/4-53
#   inflating: small_10_100/4-52
#   inflating: small_10_100/4-51
#   inflating: small_10_100/4-50
#   inflating: small_10_100/4-49
#   inflating: small_10_100/4-48
#   inflating: small_10_100/4-47
#   inflating: small_10_100/4-46
#   inflating: small_10_100/4-45
#   inflating: small_10_100/4-44
#   inflating: small_10_100/4-43
#   inflating: small_10_100/4-42
#   inflating: small_10_100/4-41
#   inflating: small_10_100/4-40
#   inflating: small_10_100/4-39
#   inflating: small_10_100/4-38
#   inflating: small_10_100/4-37
#   inflating: small_10_100/4-36
#   inflating: small_10_100/4-35
#   inflating: small_10_100/4-34
#   inflating: small_10_100/4-33
#   inflating: small_10_100/4-32
#   inflating: small_10_100/4-31
#   inflating: small_10_100/4-30
#   inflating: small_10_100/4-29
#   inflating: small_10_100/4-28
#   inflating: small_10_100/4-27
#   inflating: small_10_100/4-26
#   inflating: small_10_100/4-25
#   inflating: small_10_100/4-24
#   inflating: small_10_100/4-23
#   inflating: small_10_100/4-22
#   inflating: small_10_100/4-21
#   inflating: small_10_100/4-20
#   inflating: small_10_100/4-19
#   inflating: small_10_100/4-18
#   inflating: small_10_100/4-17
#   inflating: small_10_100/4-16
#   inflating: small_10_100/4-15
#   inflating: small_10_100/4-14
#   inflating: small_10_100/4-13
#   inflating: small_10_100/4-12
#   inflating: small_10_100/4-11
#   inflating: small_10_100/4-10
#   inflating: small_10_100/4-9
#   inflating: small_10_100/4-8
#   inflating: small_10_100/4-7
#   inflating: small_10_100/4-6
#   inflating: small_10_100/4-5
#   inflating: small_10_100/4-4
#   inflating: small_10_100/4-3
#   inflating: small_10_100/4-2
#   inflating: small_10_100/4-1
#   inflating: small_10_100/4-0
#   inflating: small_10_100/3-99
#   inflating: small_10_100/3-98
#   inflating: small_10_100/3-97
#   inflating: small_10_100/3-96
#   inflating: small_10_100/3-95
#   inflating: small_10_100/3-94
#   inflating: small_10_100/3-93
#   inflating: small_10_100/3-92
#   inflating: small_10_100/3-91
#   inflating: small_10_100/3-90
#   inflating: small_10_100/3-89
#   inflating: small_10_100/3-88
#   inflating: small_10_100/3-87
#   inflating: small_10_100/3-86
#   inflating: small_10_100/3-85
#   inflating: small_10_100/3-84
#   inflating: small_10_100/6-39
#   inflating: small_10_100/6-38
#   inflating: small_10_100/6-37
#   inflating: small_10_100/6-36
#   inflating: small_10_100/6-35
#   inflating: small_10_100/6-34
#   inflating: small_10_100/6-33
#   inflating: small_10_100/6-32
#   inflating: small_10_100/6-31
#   inflating: small_10_100/6-30
#   inflating: small_10_100/6-29
#   inflating: small_10_100/6-28
#   inflating: small_10_100/6-27
#   inflating: small_10_100/6-26
#   inflating: small_10_100/6-25
#   inflating: small_10_100/6-24
#   inflating: small_10_100/6-23
#   inflating: small_10_100/6-22
#   inflating: small_10_100/6-21
#   inflating: small_10_100/6-20
#   inflating: small_10_100/6-19
#   inflating: small_10_100/6-18
#   inflating: small_10_100/6-17
#   inflating: small_10_100/6-16
#   inflating: small_10_100/6-15
#   inflating: small_10_100/6-14
#   inflating: small_10_100/6-13
#   inflating: small_10_100/6-12
#   inflating: small_10_100/6-11
#   inflating: small_10_100/6-10
#   inflating: small_10_100/6-9
#   inflating: small_10_100/6-8
#   inflating: small_10_100/6-7
#   inflating: small_10_100/6-6
#   inflating: small_10_100/6-5
#   inflating: small_10_100/6-4
#   inflating: small_10_100/6-3
#   inflating: small_10_100/6-2
#   inflating: small_10_100/6-1
#   inflating: small_10_100/6-0
#   inflating: small_10_100/5-99
#   inflating: small_10_100/5-98
#   inflating: small_10_100/5-97
#   inflating: small_10_100/5-96
#   inflating: small_10_100/5-95
#   inflating: small_10_100/5-94
#   inflating: small_10_100/5-93
#   inflating: small_10_100/5-92
#   inflating: small_10_100/5-91
#   inflating: small_10_100/5-90
#   inflating: small_10_100/5-89
#   inflating: small_10_100/5-88
#   inflating: small_10_100/5-87
#   inflating: small_10_100/5-86
#   inflating: small_10_100/5-85
#   inflating: small_10_100/5-84
#   inflating: small_10_100/5-83
#   inflating: small_10_100/5-82
#   inflating: small_10_100/5-81
#   inflating: small_10_100/5-80
#   inflating: small_10_100/5-79
#   inflating: small_10_100/5-78
#   inflating: small_10_100/5-77
#   inflating: small_10_100/5-76
#   inflating: small_10_100/5-75
#   inflating: small_10_100/5-74
#   inflating: small_10_100/5-73
#   inflating: small_10_100/5-72
#   inflating: small_10_100/5-71
#   inflating: small_10_100/5-70
#   inflating: small_10_100/5-69
#   inflating: small_10_100/5-68
#   inflating: small_10_100/5-67
#   inflating: small_10_100/5-66
#   inflating: small_10_100/5-65
#   inflating: small_10_100/5-64
#   inflating: small_10_100/5-63
#   inflating: small_10_100/5-62
#   inflating: small_10_100/5-61
#   inflating: small_10_100/5-60
#   inflating: small_10_100/5-59
#   inflating: small_10_100/5-58
#   inflating: small_10_100/5-57
#   inflating: small_10_100/5-56
#   inflating: small_10_100/5-55
#   inflating: small_10_100/5-54
#   inflating: small_10_100/5-53
#   inflating: small_10_100/5-52
#   inflating: small_10_100/5-51
#   inflating: small_10_100/5-50
#   inflating: small_10_100/5-49
#   inflating: small_10_100/5-48
#   inflating: small_10_100/5-47
#   inflating: small_10_100/5-46
#   inflating: small_10_100/5-45
#   inflating: small_10_100/5-44
#   inflating: small_10_100/5-43
#   inflating: small_10_100/5-42
#   inflating: small_10_100/5-41
#   inflating: small_10_100/5-40
#   inflating: small_10_100/5-39
#   inflating: small_10_100/5-38
#   inflating: small_10_100/5-37
#   inflating: small_10_100/5-36
#   inflating: small_10_100/5-35
#   inflating: small_10_100/5-34
#   inflating: small_10_100/5-33
#   inflating: small_10_100/5-32
#   inflating: small_10_100/5-31
#   inflating: small_10_100/5-30
#   inflating: small_10_100/5-29
#   inflating: small_10_100/5-28
#   inflating: small_10_100/5-27
#   inflating: small_10_100/5-26
#   inflating: small_10_100/5-25
#   inflating: small_10_100/5-24
#   inflating: small_10_100/5-23
#   inflating: small_10_100/5-22
#   inflating: small_10_100/5-21
#   inflating: small_10_100/5-20
#   inflating: small_10_100/5-19
#   inflating: small_10_100/5-18
#   inflating: small_10_100/5-17
#   inflating: small_10_100/5-16
#   inflating: small_10_100/5-15
#   inflating: small_10_100/5-14
#   inflating: small_10_100/5-13
#   inflating: small_10_100/5-12
#   inflating: small_10_100/7-67
#   inflating: small_10_100/7-66
#   inflating: small_10_100/7-65
#   inflating: small_10_100/7-64
#   inflating: small_10_100/7-63
#   inflating: small_10_100/7-62
#   inflating: small_10_100/7-61
#   inflating: small_10_100/7-60
#   inflating: small_10_100/7-59
#   inflating: small_10_100/7-58
#   inflating: small_10_100/7-57
#   inflating: small_10_100/7-56
#   inflating: small_10_100/7-55
#   inflating: small_10_100/7-54
#   inflating: small_10_100/7-53
#   inflating: small_10_100/7-52
#   inflating: small_10_100/7-51
#   inflating: small_10_100/7-50
#   inflating: small_10_100/7-49
#   inflating: small_10_100/7-48
#   inflating: small_10_100/7-47
#   inflating: small_10_100/7-46
#   inflating: small_10_100/7-45
#   inflating: small_10_100/7-44
#   inflating: small_10_100/7-43
#   inflating: small_10_100/7-42
#   inflating: small_10_100/7-41
#   inflating: small_10_100/7-40
#   inflating: small_10_100/7-39
#   inflating: small_10_100/7-38
#   inflating: small_10_100/7-37
#   inflating: small_10_100/7-36
#   inflating: small_10_100/7-35
#   inflating: small_10_100/7-34
#   inflating: small_10_100/7-33
#   inflating: small_10_100/7-32
#   inflating: small_10_100/7-31
#   inflating: small_10_100/7-30
#   inflating: small_10_100/7-29
#   inflating: small_10_100/7-28
#   inflating: small_10_100/7-27
#   inflating: small_10_100/7-26
#   inflating: small_10_100/7-25
#   inflating: small_10_100/7-24
#   inflating: small_10_100/7-23
#   inflating: small_10_100/7-22
#   inflating: small_10_100/7-21
#   inflating: small_10_100/7-20
#   inflating: small_10_100/7-19
#   inflating: small_10_100/7-18
#   inflating: small_10_100/7-17
#   inflating: small_10_100/7-16
#   inflating: small_10_100/7-15
#   inflating: small_10_100/7-14
#   inflating: small_10_100/7-13
#   inflating: small_10_100/7-12
#   inflating: small_10_100/7-11
#   inflating: small_10_100/7-10
#   inflating: small_10_100/7-9
#   inflating: small_10_100/7-8
#   inflating: small_10_100/7-7
#   inflating: small_10_100/7-6
#   inflating: small_10_100/7-5
#   inflating: small_10_100/7-4
#   inflating: small_10_100/7-3
#   inflating: small_10_100/7-2
#   inflating: small_10_100/7-1
#   inflating: small_10_100/7-0
#   inflating: small_10_100/6-99
#   inflating: small_10_100/6-98
#   inflating: small_10_100/6-97
#   inflating: small_10_100/6-96
#   inflating: small_10_100/6-95
#   inflating: small_10_100/6-94
#   inflating: small_10_100/6-93
#   inflating: small_10_100/6-92
#   inflating: small_10_100/6-91
#   inflating: small_10_100/6-90
#   inflating: small_10_100/6-89
#   inflating: small_10_100/6-88
#   inflating: small_10_100/6-87
#   inflating: small_10_100/6-86
#   inflating: small_10_100/6-85
#   inflating: small_10_100/6-84
#   inflating: small_10_100/6-83
#   inflating: small_10_100/6-82
#   inflating: small_10_100/6-81
#   inflating: small_10_100/6-80
#   inflating: small_10_100/6-79
#   inflating: small_10_100/6-78
#   inflating: small_10_100/6-77
#   inflating: small_10_100/6-76
#   inflating: small_10_100/6-75
#   inflating: small_10_100/6-74
#   inflating: small_10_100/6-73
#   inflating: small_10_100/6-72
#   inflating: small_10_100/6-71
#   inflating: small_10_100/6-70
#   inflating: small_10_100/6-69
#   inflating: small_10_100/6-68
#   inflating: small_10_100/6-67
#   inflating: small_10_100/6-66
#   inflating: small_10_100/6-65
#   inflating: small_10_100/6-64
#   inflating: small_10_100/6-63
#   inflating: small_10_100/6-62
#   inflating: small_10_100/6-61
#   inflating: small_10_100/6-60
#   inflating: small_10_100/6-59
#   inflating: small_10_100/6-58
#   inflating: small_10_100/6-57
#   inflating: small_10_100/6-56
#   inflating: small_10_100/6-55
#   inflating: small_10_100/6-54
#   inflating: small_10_100/6-53
#   inflating: small_10_100/6-52
#   inflating: small_10_100/6-51
#   inflating: small_10_100/6-50
#   inflating: small_10_100/6-49
#   inflating: small_10_100/6-48
#   inflating: small_10_100/6-47
#   inflating: small_10_100/6-46
#   inflating: small_10_100/6-45
#   inflating: small_10_100/6-44
#   inflating: small_10_100/6-43
#   inflating: small_10_100/6-42
#   inflating: small_10_100/6-41
#   inflating: small_10_100/6-40
#   inflating: small_10_100/8-95
#   inflating: small_10_100/8-94
#   inflating: small_10_100/8-93
#   inflating: small_10_100/8-92
#   inflating: small_10_100/8-91
#   inflating: small_10_100/8-90
#   inflating: small_10_100/8-89
#   inflating: small_10_100/8-88
#   inflating: small_10_100/8-87
#   inflating: small_10_100/8-86
#   inflating: small_10_100/8-85
#   inflating: small_10_100/8-84
#   inflating: small_10_100/8-83
#   inflating: small_10_100/8-82
#   inflating: small_10_100/8-81
#   inflating: small_10_100/8-80
#   inflating: small_10_100/8-79
#   inflating: small_10_100/8-78
#   inflating: small_10_100/8-77
#   inflating: small_10_100/8-76
#   inflating: small_10_100/8-75
#   inflating: small_10_100/8-74
#   inflating: small_10_100/8-73
#   inflating: small_10_100/8-72
#   inflating: small_10_100/8-71
#   inflating: small_10_100/8-70
#   inflating: small_10_100/8-69
#   inflating: small_10_100/8-68
#   inflating: small_10_100/8-67
#   inflating: small_10_100/8-66
#   inflating: small_10_100/8-65
#   inflating: small_10_100/8-64
#   inflating: small_10_100/8-63
#   inflating: small_10_100/8-62
#   inflating: small_10_100/8-61
#   inflating: small_10_100/8-60
#   inflating: small_10_100/8-59
#   inflating: small_10_100/8-58
#   inflating: small_10_100/8-57
#   inflating: small_10_100/8-56
#   inflating: small_10_100/8-55
#   inflating: small_10_100/8-54
#   inflating: small_10_100/8-53
#   inflating: small_10_100/8-52
#   inflating: small_10_100/8-51
#   inflating: small_10_100/8-50
#   inflating: small_10_100/8-49
#   inflating: small_10_100/8-48
#   inflating: small_10_100/8-47
#   inflating: small_10_100/8-46
#   inflating: small_10_100/8-45
#   inflating: small_10_100/8-44
#   inflating: small_10_100/8-43
#   inflating: small_10_100/8-42
#   inflating: small_10_100/8-41
#   inflating: small_10_100/8-40
#   inflating: small_10_100/8-39
#   inflating: small_10_100/8-38
#   inflating: small_10_100/8-37
#   inflating: small_10_100/8-36
#   inflating: small_10_100/8-35
#   inflating: small_10_100/8-34
#   inflating: small_10_100/8-33
#   inflating: small_10_100/8-32
#   inflating: small_10_100/8-31
#   inflating: small_10_100/8-30
#   inflating: small_10_100/8-29
#   inflating: small_10_100/8-28
#   inflating: small_10_100/8-27
#   inflating: small_10_100/8-26
#   inflating: small_10_100/8-25
#   inflating: small_10_100/8-24
#   inflating: small_10_100/8-23
#   inflating: small_10_100/8-22
#   inflating: small_10_100/8-21
#   inflating: small_10_100/8-20
#   inflating: small_10_100/8-19
#   inflating: small_10_100/8-18
#   inflating: small_10_100/8-17
#   inflating: small_10_100/8-16
#   inflating: small_10_100/8-15
#   inflating: small_10_100/8-14
#   inflating: small_10_100/8-13
#   inflating: small_10_100/8-12
#   inflating: small_10_100/8-11
#   inflating: small_10_100/8-10
#   inflating: small_10_100/8-9
#   inflating: small_10_100/8-8
#   inflating: small_10_100/8-7
#   inflating: small_10_100/8-6
#   inflating: small_10_100/8-5
#   inflating: small_10_100/8-4
#   inflating: small_10_100/8-3
#   inflating: small_10_100/8-2
#   inflating: small_10_100/8-1
#   inflating: small_10_100/8-0
#   inflating: small_10_100/7-99
#   inflating: small_10_100/7-98
#   inflating: small_10_100/7-97
#   inflating: small_10_100/7-96
#   inflating: small_10_100/7-95
#   inflating: small_10_100/7-94
#   inflating: small_10_100/7-93
#   inflating: small_10_100/7-92
#   inflating: small_10_100/7-91
#   inflating: small_10_100/7-90
#   inflating: small_10_100/7-89
#   inflating: small_10_100/7-88
#   inflating: small_10_100/7-87
#   inflating: small_10_100/7-86
#   inflating: small_10_100/7-85
#   inflating: small_10_100/7-84
#   inflating: small_10_100/7-83
#   inflating: small_10_100/7-82
#   inflating: small_10_100/7-81
#   inflating: small_10_100/7-80
#   inflating: small_10_100/7-79
#   inflating: small_10_100/7-78
#   inflating: small_10_100/7-77
#   inflating: small_10_100/7-76
#   inflating: small_10_100/7-75
#   inflating: small_10_100/7-74
#   inflating: small_10_100/7-73
#   inflating: small_10_100/7-72
#   inflating: small_10_100/7-71
#   inflating: small_10_100/7-70
#   inflating: small_10_100/7-69
#   inflating: small_10_100/7-68
#   inflating: small_10_100/9-99
#   inflating: small_10_100/9-98
#   inflating: small_10_100/9-97
#   inflating: small_10_100/9-96
#   inflating: small_10_100/9-95
#   inflating: small_10_100/9-94
#   inflating: small_10_100/9-93
#   inflating: small_10_100/9-92
#   inflating: small_10_100/9-91
#   inflating: small_10_100/9-90
#   inflating: small_10_100/9-89
#   inflating: small_10_100/9-88
#   inflating: small_10_100/9-87
#   inflating: small_10_100/9-86
#   inflating: small_10_100/9-85
#   inflating: small_10_100/9-84
#   inflating: small_10_100/9-83
#   inflating: small_10_100/9-82
#   inflating: small_10_100/9-81
#   inflating: small_10_100/9-80
#   inflating: small_10_100/9-79
#   inflating: small_10_100/9-78
#   inflating: small_10_100/9-77
#   inflating: small_10_100/9-76
#   inflating: small_10_100/9-75
#   inflating: small_10_100/9-74
#   inflating: small_10_100/9-73
#   inflating: small_10_100/9-72
#   inflating: small_10_100/9-71
#   inflating: small_10_100/9-70
#   inflating: small_10_100/9-69
#   inflating: small_10_100/9-68
#   inflating: small_10_100/9-67
#   inflating: small_10_100/9-66
#   inflating: small_10_100/9-65
#   inflating: small_10_100/9-64
#   inflating: small_10_100/9-63
#   inflating: small_10_100/9-62
#   inflating: small_10_100/9-61
#   inflating: small_10_100/9-60
#   inflating: small_10_100/9-59
#   inflating: small_10_100/9-58
#   inflating: small_10_100/9-57
#   inflating: small_10_100/9-56
#   inflating: small_10_100/9-55
#   inflating: small_10_100/9-54
#   inflating: small_10_100/9-53
#   inflating: small_10_100/9-52
#   inflating: small_10_100/9-51
#   inflating: small_10_100/9-50
#   inflating: small_10_100/9-49
#   inflating: small_10_100/9-48
#   inflating: small_10_100/9-47
#   inflating: small_10_100/9-46
#   inflating: small_10_100/9-45
#   inflating: small_10_100/9-44
#   inflating: small_10_100/9-43
#   inflating: small_10_100/9-42
#   inflating: small_10_100/9-41
#   inflating: small_10_100/9-40
#   inflating: small_10_100/9-39
#   inflating: small_10_100/9-38
#   inflating: small_10_100/9-37
#   inflating: small_10_100/9-36
#   inflating: small_10_100/9-35
#   inflating: small_10_100/9-34
#   inflating: small_10_100/9-33
#   inflating: small_10_100/9-32
#   inflating: small_10_100/9-31
#   inflating: small_10_100/9-30
#   inflating: small_10_100/9-29
#   inflating: small_10_100/9-28
#   inflating: small_10_100/9-27
#   inflating: small_10_100/9-26
#   inflating: small_10_100/9-25
#   inflating: small_10_100/9-24
#   inflating: small_10_100/9-23
#   inflating: small_10_100/9-22
#   inflating: small_10_100/9-21
#   inflating: small_10_100/9-20
#   inflating: small_10_100/9-19
#   inflating: small_10_100/9-18
#   inflating: small_10_100/9-17
#   inflating: small_10_100/9-16
#   inflating: small_10_100/9-15
#   inflating: small_10_100/9-14
#   inflating: small_10_100/9-13
#   inflating: small_10_100/9-12
#   inflating: small_10_100/9-11
#   inflating: small_10_100/9-10
#   inflating: small_10_100/9-9
#   inflating: small_10_100/9-8
#   inflating: small_10_100/9-7
#   inflating: small_10_100/9-6
#   inflating: small_10_100/9-5
#   inflating: small_10_100/9-4
#   inflating: small_10_100/9-3
#   inflating: small_10_100/9-2
#   inflating: small_10_100/9-1
#   inflating: small_10_100/9-0
#   inflating: small_10_100/8-99
#   inflating: small_10_100/8-98
#   inflating: small_10_100/8-97
#   inflating: small_10_100/8-96

# %%
# %tensorflow_version 2.x
# %load_ext tensorboard
import numpy as np
from sklearn.utils import shuffle

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping
from tensorflow.keras.regularizers import l2

# Additional Packages
from tensorflow.keras.layers import BatchNormalization, Activation, AveragePooling1D, ELU
from tensorflow.keras.optimizers import Adam, Adamax, RMSprop
from keras.initializers import glorot_uniform
from pathlib import Path
from keras.callbacks import CSVLogger
import shutil
import os


import tensorflow as tf
#tf.logging.set_verbosity(tf.logging.ERROR)
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
# Run if switching from Large_95_100 Dataset to Full Dataset or vice versa.
# Both Datasets have the same folder name which can cause data to overlap
#shutil.rmtree('/content/undefended')

# %%
# Global Definitions
# Set the data_path based on the Dataset
# /content/small_10_100 - small_10_100 
# /content/large_10_1000 - large_10_1000
# /content/undefended - large_95_100, Full
data_path="/content/undefended/"  # trace data path
data_path="/content/small_10_100/"

# Change the num_sites based on the dataset
# 10 - small_10_100, large_10_1000
# 95 - large_95_100, full
num_sites=10              # number of sites (max 95)
num_instances=100         # number of instances per site (max 100)
file_ext=""                # trace file extension

# Changable Hyperparameters
# Set the input units (2000, 3000, 5000, etc)
max_length = 8000           # maximum number of packet directions to use

# %%
# Information about the dataset
from collections import defaultdict
count_dict = defaultdict(int)
samples = []
for filename in os.listdir(data_path):
    x, y = filename.split("-")
    count_dict[x] += 1
for x, count in count_dict.items():
    samples.append(count)

print("# of Classes: "+str(len(samples)))
print("Avg # of Samples per Class: "+str(np.average(samples)))
# Out:
# # of Classes: 10
# Avg # of Samples per Class: 100.0

# %%
from tensorflow.python.ops.gen_linalg_ops import BatchCholesky

def get_data():
    """
    :return: a numpy ndarray of dimension (m x (n+1)) containing direction data
        loaded from the files, where `m` is the number of data samples and `n`
        is length of direction packets (restricted to 500 to consume less
        computation time and memory). The last column in the data contains the
        class labels of the `m` samples, which are the website numbers.

    This function loads the data from the files and creates a numpy data matrix
    with each row as a data sample and the columns containing packet direction.
    The last column of the data is the label, which is the website to which the
    instance belongs.
    """
    # read data from files
    print("loading data...")
    data = [] 
    for site in range(0, num_sites):
        for instance in range(0, num_instances):
            file_name = str(site) + "-" + str(instance)
            # Directory of the raw data
            with open(data_path + file_name + file_ext, "r") as file_pt:
                directions = []
                for line in file_pt:
                    x = line.strip().split('\t')
                    directions.append(1 if float(x[1]) > 0 else -1)
                if len(directions) < max_length:
                    zend = max_length - len(directions)
                    directions.extend([0] * zend)
                elif len(directions) > max_length:
                    directions = directions[:max_length]
                data.append(directions + [site])
    print("done")
    return np.array(data)

def split_data(X, Y, fraction=0.80, balance_dist=False):
    """
    :param X: a numpy ndarray of dimension (m x n) containing data samples
    :param Y: a numpy ndarray of dimension (m x 1) containing labels for X
    :param fraction: a value between 0 and 1, which will be the fraction of
        data split into training and test sets. value of `fraction` will be the
        training data and the rest being test data.
    :param balance_dist: boolean value. The split is performed with ensured
        class balance if the value is true.
    :return: X_train, Y_train, X_test, Y_test
    """
    X, Y = shuffle(X, Y)
    m, n = X.shape
    split_index = int(round(m*fraction))
    if balance_dist:
        X_train = np.zeros(shape=(split_index, n))
        X_test = np.zeros(shape=(m-split_index, n))
        Y_train = np.zeros(shape=(split_index,))
        Y_test = np.zeros(shape=(m-split_index,))
        labels = np.unique(Y)
        ind1 = 0
        ind2 = 0
        for i in np.arange(labels.size):
            indices = np.where(Y == labels[i])[0]
            split = int(round(len(indices)*fraction))

            X_train[ind1:ind1 + split, :] = X[indices[:split], :]
            X_test[ind2:ind2+(indices.size-split), :] = X[indices[split:], :]

            Y_train[ind1:ind1 + split] = Y[indices[:split]]
            Y_test[ind2:ind2+(indices.size-split)] = Y[indices[split:]]

            ind1 += split
            ind2 += indices.size-split
        X_train, Y_train = shuffle(X_train, Y_train)
        X_test, Y_test = shuffle(X_test, Y_test)
        return X_train, Y_train, X_test, Y_test
    return X[:split_index, :], Y[:split_index], \
        X[split_index:, :], Y[split_index:]

class AWF:
    """
    This class implements the AWF Model from "Automated Web Fingerprinting 
    through Deep Learning" by V. Rimmer et al.
    https://github.com/DistriNet/DLWF
    """
    def __init__(self, num_features, num_classes):
        model = Sequential()
        kernel_size = 5
        filters = 32
        pool_size = 4
        dropout = 0.1
        batch_size = 128
        lr = 0.001

        model.add(Dropout(input_shape=(num_features, 1), rate=dropout))
        model.add(Conv1D(filters=filters, kernel_size=kernel_size, padding='valid', activation='relu', strides=1))
        model.add(MaxPooling1D(pool_size=pool_size, padding='valid'))
        model.add(Conv1D(filters=filters, kernel_size=kernel_size, padding='valid', activation='relu', strides=1))
        model.add(MaxPooling1D(pool_size=pool_size, padding='valid'))
        model.add(Flatten())
        model.add(Dense(units=num_classes, activation='softmax'))
        optimizer = RMSprop(lr=lr)
        model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
        self.model = model        
        print(self.model.summary())

    def fit(self, X_train, Y_train, batch_size, epochs, verbose):
        """
        :param X_train: a numpy ndarray of dimension (k x n) containing
            training data
        :param Y_train: a numpy ndarray of dimension (k x 1) containing
            labels for X_train
        :param batch_size: batch size to use for training
        :param epochs: number of epochs for training
        :param verbose: Console print options for training progress.
            0 - silent mode,
            1 - progress bar,
            2 - one line per epoch
        :return: None

        This method start training the model with the given data. The
        training options are configured with tensorboard and early stopping
        callbacks.

        Tensorboard could be launched by navigating to the directory
        containing this file in terminal and running the following command.
            > tensorboard --logdir graph
        """
        tboard_cb = TensorBoard(log_dir='./graph/AWF', histogram_freq=0,
                                write_graph=True, write_images=True)
        csv_logger = CSVLogger('logAWF.csv')
        self.model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs,
                       verbose=verbose, validation_split=0.20,
                       callbacks=[tboard_cb, csv_logger])

class DF:
    """
    This class implements the DF model from "Deep Fingerprinting: Undermining 
    Website Fingerprinting Defenses with Deep Learning" by P. Sirinam, M. Imani,
    M. Juarez and M. Wright
    https://github.com/deep-fingerprinting/df
    """
    def __init__(self, num_features, num_classes):
        model = Sequential()

        filter_num = ['None',32,64,128,256]
        kernel_size = ['None',8,8,8,8]
        conv_stride_size = ['None',1,1,1,1]
        pool_stride_size = ['None',4,4,4,4]
        pool_size = ['None',8,8,8,8]

        model.add(Conv1D(filters=filter_num[1], kernel_size=kernel_size[1], input_shape=(num_features, 1),
                         strides=conv_stride_size[1], padding='same',
                         name='block1_conv1'))
        model.add(BatchNormalization())
        model.add(ELU(alpha=1.0, name='block1_adv_act1'))
        model.add(Conv1D(filters=filter_num[1], kernel_size=kernel_size[1],
                         strides=conv_stride_size[1], padding='same',
                         name='block1_conv2'))
        model.add(BatchNormalization())
        model.add(ELU(alpha=1.0, name='block1_adv_act2'))
        model.add(MaxPooling1D(pool_size=pool_size[1], strides=pool_stride_size[1],
                               padding='same', name='block1_pool'))
        model.add(Dropout(0.1, name='block1_dropout'))

        model.add(Conv1D(filters=filter_num[2], kernel_size=kernel_size[2],
                         strides=conv_stride_size[2], padding='same',
                         name='block2_conv1'))
        model.add(BatchNormalization())
        model.add(Activation('relu', name='block2_act1'))

        model.add(Conv1D(filters=filter_num[2], kernel_size=kernel_size[2],
                         strides=conv_stride_size[2], padding='same',
                         name='block2_conv2'))
        model.add(BatchNormalization())
        model.add(Activation('relu', name='block2_act2'))
        model.add(MaxPooling1D(pool_size=pool_size[2], strides=pool_stride_size[3],
                               padding='same', name='block2_pool'))
        model.add(Dropout(0.1, name='block2_dropout'))

        model.add(Conv1D(filters=filter_num[3], kernel_size=kernel_size[3],
                         strides=conv_stride_size[3], padding='same',
                         name='block3_conv1'))
        model.add(BatchNormalization())
        model.add(Activation('relu', name='block3_act1'))
        model.add(Conv1D(filters=filter_num[3], kernel_size=kernel_size[3],
                         strides=conv_stride_size[3], padding='same',
                         name='block3_conv2'))
        model.add(BatchNormalization())
        model.add(Activation('relu', name='block3_act2'))
        model.add(MaxPooling1D(pool_size=pool_size[3], strides=pool_stride_size[3],
                               padding='same', name='block3_pool'))
        model.add(Dropout(0.1, name='block3_dropout'))

        model.add(Conv1D(filters=filter_num[4], kernel_size=kernel_size[4],
                         strides=conv_stride_size[4], padding='same',
                         name='block4_conv1'))
        model.add(BatchNormalization())
        model.add(Activation('relu', name='block4_act1'))
        model.add(Conv1D(filters=filter_num[4], kernel_size=kernel_size[4],
                         strides=conv_stride_size[4], padding='same',
                         name='block4_conv2'))
        model.add(BatchNormalization())
        model.add(Activation('relu', name='block4_act2'))
        model.add(MaxPooling1D(pool_size=pool_size[4], strides=pool_stride_size[4],
                               padding='same', name='block4_pool'))
        model.add(Dropout(0.1, name='block4_dropout'))

        model.add(Flatten(name='flatten'))
        model.add(Dense(512, name='fc1'))
        model.add(BatchNormalization())
        model.add(Activation('relu', name='fc1_act'))
        model.add(Dropout(0.7, name='fc1_dropout'))

        model.add(Dense(512, name='fc2'))
        model.add(BatchNormalization())
        model.add(Activation('relu', name='fc2_act'))
        model.add(Dropout(0.5, name='fc2_dropout'))

        model.add(Dense(num_classes, name='fc3'))
        model.add(Activation('softmax', name="softmax"))

        opti = Adamax(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
        model.compile(loss="categorical_crossentropy", optimizer=opti, metrics=["accuracy"])
        self.model = model
        print(self.model.summary())

    def fit(self, X_train, Y_train, batch_size, epochs, verbose):
        """
        :param X_train: a numpy ndarray of dimension (k x n) containing
            training data
        :param Y_train: a numpy ndarray of dimension (k x 1) containing
            labels for X_train
        :param batch_size: batch size to use for training
        :param epochs: number of epochs for training
        :param verbose: Console print options for training progress.
            0 - silent mode,
            1 - progress bar,
            2 - one line per epoch
        :return: None

        This method start training the model with the given data. The
        training options are configured with tensorboard and early stopping
        callbacks.

        Tensorboard could be launched by navigating to the directory
        containing this file in terminal and running the following command.
            > tensorboard --logdir graph
        """
        tboard_cb = TensorBoard(log_dir='./graph/DF', histogram_freq=0,
                                write_graph=True, write_images=True)
        csv_logger = CSVLogger('logDF.csv')
        self.model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs,
                       verbose=verbose, validation_split=0.20,
                       callbacks=[tboard_cb, csv_logger])

class CNNdefault:
    """
    This class contains a CNN architecture with the default hyperparameters to 
    model Website Traffic Fingerprinting using the direction information from 
    undefended data
    The changes to the hyperparameter on lines 17 will be applied to this 
    architecture.
    """
    def __init__(self, num_features, num_classes):
        """
        :param num_features: number of features (columns) in the data (X)
        :param num_classes: number of unique labels in the data (number of
            websites)
        """
        model = Sequential()
        num_filters = [4, 4]
        filter_sizes = [5, 5]
        l2_lambda = 0.0001
        # activation: 'tanh', 'relu', 'elu', 'selu', 'sigmoid' 
        # layer 1
        model.add(Conv1D(num_filters[0], filter_sizes[0]
                        , input_shape=(num_features, 1), padding="same"
                         , activation='tanh', kernel_regularizer=l2(l2_lambda)))
        # Hidden layers
        #model.add(BatchNormalization())
        model.add(Conv1D(num_filters[1], filter_sizes[1], activation='tanh'
                         , kernel_regularizer=l2(l2_lambda)))
        #model.add(BatchNormalization())
        model.add(MaxPooling1D(2))        
        model.add(Flatten())
        # dropout layer
        model.add(Dropout(0.5))
        # final layer
        model.add(Dense(num_classes, activation='softmax'))

        # optimization function
        #opti = RMSprop(lr=0.03)
        #opti = Adam(lr=0.03)
        #opti = Adamax(lr=0.03)
        opti = SGD(lr=0.03)
        model.compile(loss='categorical_crossentropy', optimizer=opti, 
                      metrics=['accuracy'])
        self.model = model
        print(self.model.summary())
        

    def fit(self, X_train, Y_train, batch_size, epochs, verbose):
        """
        :param X_train: a numpy ndarray of dimension (k x n) containing
            training data
        :param Y_train: a numpy ndarray of dimension (k x 1) containing
            labels for X_train
        :param batch_size: batch size to use for training
        :param epochs: number of epochs for training
        :param verbose: Console print options for training progress.
            0 - silent mode,
            1 - progress bar,
            2 - one line per epoch
        :return: None

        This method start training the model with the given data. The
        training options are configured with tensorboard and early stopping
        callbacks.

        Tensorboard could be launched by navigating to the directory
        containing this file in terminal and running the following command.
            > tensorboard --logdir graph
        """
        tboard_cb = TensorBoard(log_dir='./graph/cnn-basic', histogram_freq=0,
                                write_graph=True, write_images=True)
        csv_logger = CSVLogger('logBasic.csv')

        # Uncomment lines 323 - 326 and comment lines 328 - 330 to implement 
        # early stopping

        #early_stopping_cb = EarlyStopping(monitor="val_loss", patience=3)
        #self.model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs,
        #               verbose=verbose, validation_split=0.20,
        #               callbacks=[tboard_cb, early_stopping_cb, csv_logger])
        
        self.model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs,
                       verbose=verbose, validation_split=0.20,
                       callbacks=[tboard_cb, csv_logger])
        
class CNNbest:
    """
    This class contains a CNN architecture with the best possible hyperparameters
    to model Website Traffic Fingerprinting using the direction information from 
    undefended data.
    The changes to the hyperparameters on lines 17, 19, 21, 23 and 25 will be 
    applied to this architecture.
    """
    def __init__(self, num_features, num_classes):
        """
        :param num_features: number of features (columns) in the data (X)
        :param num_classes: number of unique labels in the data (number of
            websites)
        """
        model = Sequential()
        num_filters = [4, 4]
        filter_sizes = [5, 5]
        l2_lambda = 0.0001
        # layer 1
        model.add(Conv1D(num_filters[0], filter_sizes[0]
                        , input_shape=(num_features, 1), padding="same"
                         , activation='relu', 
                         kernel_regularizer=l2(l2_lambda)))
        # hidden layers
        model.add(BatchNormalization())
        model.add(Conv1D(num_filters[1], filter_sizes[1], 
                         activation='relu'
                         , kernel_regularizer=l2(l2_lambda)))
        model.add(BatchNormalization())
        model.add(MaxPooling1D(2))
        model.add(Flatten())
        model.add(Dropout(0.9))
        # final layer
        model.add(Dense(num_classes, activation='softmax'))

        # optimization function
        opti = SGD(lr=0.03)
        model.compile(loss='categorical_crossentropy', optimizer=opti, 
                      metrics=['accuracy'])
        self.model = model
        print(self.model.summary())
        plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=False)

    def fit(self, X_train, Y_train, batch_size, epochs, verbose):
        """
        :param X_train: a numpy ndarray of dimension (k x n) containing
            training data
        :param Y_train: a numpy ndarray of dimension (k x 1) containing
            labels for X_train
        :param batch_size: batch size to use for training
        :param epochs: number of epochs for training
        :param verbose: Console print options for training progress.
            0 - silent mode,
            1 - progress bar,
            2 - one line per epoch
        :return: None

        This method start training the model with the given data. The
        training options are configured with tensorboard and early stopping
        callbacks.

        Tensorboard could be launched by navigating to the directory
        containing this file in terminal and running the following command.
            > tensorboard --logdir graph
        """
        tboard_cb = TensorBoard(log_dir='./graph/cnn-best', histogram_freq=0,
                                write_graph=True, write_images=True)
        
        # Uncomment lines 412 - 415 and comment lines 417 - 420 to implement 
        # early stopping

        #early_stopping_cb = EarlyStopping(monitor="val_loss", patience=3)
        #self.model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs,
        #               verbose=verbose, validation_split=0.20,
        #               callbacks=[tboard_cb, early_stopping_cb])

        csv_logger = CSVLogger('logBest.csv')
        self.model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs,
                       verbose=verbose, validation_split=0.20,
                       callbacks=[tboard_cb, csv_logger])

def main():
    # Load the data and create X and Y matrices
    data = get_data()
    num_features = data.shape[1] - 1
    X = data[:, :num_features]
    Y = data[:, -1]
    
    # split the data into training and test set
    X_train, Y_train, X_test, Y_test = split_data(X, Y, 0.85, balance_dist=True)        
    X_train = np.expand_dims(X_train, axis=2)
    X_test = np.expand_dims(X_test, axis=2)
    Y_train = to_categorical(Y_train)
    Y_test = to_categorical(Y_test)
    print(X[0])

    # instantiate the model and train on the data
    # Set the epoch value (default was 500, with early stopping), works for 
    # current datasets with 30 and early stopping disabled.

    # Uncomment to instantiate and train the default CNN model
    #model = CNNdefault(num_features, Y_train.shape[1])
    #model.fit(X_train, Y_train, batch_size=25, epochs=30, verbose=1)

    # Uncomment to instantiate and train the best CNN model
    model = CNNbest(num_features, Y_train.shape[1])
    model.fit(X_train, Y_train, batch_size=25, epochs=30, verbose=1)
    
    # Uncomment to instantiate and train the AWF CNN model 
    #model = AWF(num_features, Y_train.shape[1])
    #model.fit(X_train, Y_train, batch_size=128, epochs=30, verbose=1)
    
    # Uncomment to instantiate and train the DF CNN model 
    #model = DF(num_features, Y_train.shape[1])
    #model.fit(X_train, Y_train, batch_size=128, epochs=30, verbose=1)
    
    # Evaluate the trained model on test data and print the accuracy
    
    score = model.model.evaluate(X_test, Y_test, batch_size=100)
    accuracy = round(score[1]*100, 2)
    loss = round(score[0], 2)
    print("Test accuracy: ", round(score[1]*100, 2))
    print("Test loss: ", round(score[0], 2))
    return accuracy, loss

# %%
if __name__ == '__main__':
  main()
# Out:
# loading data...
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# done
# [ 1 -1 -1 ...  0  0  0]
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 8000, 4)           24
#
#  batch_normalization_2 (Batc  (None, 8000, 4)          16
#  hNormalization)
#
#  conv1d_3 (Conv1D)           (None, 7996, 4)           84
#
#  batch_normalization_3 (Batc  (None, 7996, 4)          16
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 3998, 4)          0
#  1D)
#
#  flatten_1 (Flatten)         (None, 15992)             0
#
#  dropout_1 (Dropout)         (None, 15992)             0
#
#  dense_1 (Dense)             (None, 10)                159930
#
# =================================================================
# Total params: 160,070
# Trainable params: 160,054
# Non-trainable params: 16
# _________________________________________________________________
# None
# Epoch 1/30
# 28/28 [==============================] - 2s 19ms/step - loss: 5.4588 - accuracy: 0.3618 - val_loss: 1.6384 - val_accuracy: 0.5176
# Epoch 2/30
# 28/28 [==============================] - 0s 9ms/step - loss: 2.0015 - accuracy: 0.6250 - val_loss: 1.5226 - val_accuracy: 0.3765
# Epoch 3/30
# 28/28 [==============================] - 0s 10ms/step - loss: 1.1706 - accuracy: 0.6868 - val_loss: 1.3272 - val_accuracy: 0.6882
# Epoch 4/30
# 28/28 [==============================] - 0s 11ms/step - loss: 0.8575 - accuracy: 0.7485 - val_loss: 1.3379 - val_accuracy: 0.5118
# Epoch 5/30
# 28/28 [==============================] - 0s 11ms/step - loss: 0.8286 - accuracy: 0.7412 - val_loss: 1.1548 - val_accuracy: 0.7412
# Epoch 6/30
# 28/28 [==============================] - 0s 12ms/step - loss: 0.6303 - accuracy: 0.8029 - val_loss: 1.3472 - val_accuracy: 0.6471
# Epoch 7/30
# 28/28 [==============================] - 0s 10ms/step - loss: 0.6942 - accuracy: 0.7897 - val_loss: 0.9905 - val_accuracy: 0.7412
# Epoch 8/30
# 28/28 [==============================] - 0s 12ms/step - loss: 0.5751 - accuracy: 0.8176 - val_loss: 0.9818 - val_accuracy: 0.7412
# Epoch 9/30
# 28/28 [==============================] - 0s 12ms/step - loss: 0.5587 - accuracy: 0.8221 - val_loss: 0.6678 - val_accuracy: 0.8765
# Epoch 10/30
# 28/28 [==============================] - 0s 11ms/step - loss: 0.5205 - accuracy: 0.8441 - val_loss: 0.6562 - val_accuracy: 0.8176
# Epoch 11/30
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5143 - accuracy: 0.8309 - val_loss: 0.6800 - val_accuracy: 0.7647
# Epoch 12/30
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5042 - accuracy: 0.8485 - val_loss: 0.5690 - val_accuracy: 0.8588
# Epoch 13/30
# 28/28 [==============================] - 0s 8ms/step - loss: 0.4600 - accuracy: 0.8456 - val_loss: 0.4622 - val_accuracy: 0.9059
# Epoch 14/30
# 28/28 [==============================] - 0s 9ms/step - loss: 0.4302 - accuracy: 0.8691 - val_loss: 0.4642 - val_accuracy: 0.9000
# Epoch 15/30
# 28/28 [==============================] - 0s 8ms/step - loss: 0.4114 - accuracy: 0.8721 - val_loss: 0.4164 - val_accuracy: 0.9000
# Epoch 16/30
# 28/28 [==============================] - 0s 8ms/step - loss: 0.4019 - accuracy: 0.8809 - val_loss: 0.3646 - val_accuracy: 0.9235
# Epoch 17/30
# 28/28 [==============================] - 0s 9ms/step - loss: 0.3102 - accuracy: 0.9000 - val_loss: 0.3221 - val_accuracy: 0.9235
# Epoch 18/30
# 28/28 [==============================] - 0s 8ms/step - loss: 0.3143 - accuracy: 0.9059 - val_loss: 0.3109 - val_accuracy: 0.9059
# Epoch 19/30
# 28/28 [==============================] - 0s 8ms/step - loss: 0.3725 - accuracy: 0.8824 - val_loss: 0.2910 - val_accuracy: 0.9235
# Epoch 20/30
# 28/28 [==============================] - 0s 8ms/step - loss: 0.3198 - accuracy: 0.8956 - val_loss: 0.3174 - val_accuracy: 0.9059
# Epoch 21/30
# 28/28 [==============================] - 0s 9ms/step - loss: 0.3244 - accuracy: 0.9059 - val_loss: 0.2900 - val_accuracy: 0.9294
# Epoch 22/30
# 28/28 [==============================] - 0s 8ms/step - loss: 0.3188 - accuracy: 0.9103 - val_loss: 0.2822 - val_accuracy: 0.9118
# Epoch 23/30
# 28/28 [==============================] - 0s 8ms/step - loss: 0.2791 - accuracy: 0.9176 - val_loss: 0.2705 - val_accuracy: 0.9294
# Epoch 24/30
# 28/28 [==============================] - 0s 8ms/step - loss: 0.3070 - accuracy: 0.9088 - val_loss: 0.2707 - val_accuracy: 0.9294
# Epoch 25/30
# 28/28 [==============================] - 0s 9ms/step - loss: 0.2870 - accuracy: 0.9088 - val_loss: 0.2423 - val_accuracy: 0.9353
# Epoch 26/30
# 28/28 [==============================] - 0s 7ms/step - loss: 0.2747 - accuracy: 0.9000 - val_loss: 0.2711 - val_accuracy: 0.9412
# Epoch 27/30
# 28/28 [==============================] - 0s 9ms/step - loss: 0.2819 - accuracy: 0.9206 - val_loss: 0.2788 - val_accuracy: 0.9235
# Epoch 28/30
# 28/28 [==============================] - 0s 9ms/step - loss: 0.2461 - accuracy: 0.9147 - val_loss: 0.2715 - val_accuracy: 0.9412
# Epoch 29/30
# 28/28 [==============================] - 0s 9ms/step - loss: 0.2556 - accuracy: 0.9294 - val_loss: 0.2615 - val_accuracy: 0.9294
# Epoch 30/30
# 28/28 [==============================] - 0s 7ms/step - loss: 0.2302 - accuracy: 0.9279 - val_loss: 0.2840 - val_accuracy: 0.9118
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2061 - accuracy: 0.9467
# Test accuracy:  94.67
# Test loss:  0.21

# %%
# %tensorboard --logdir graph/
